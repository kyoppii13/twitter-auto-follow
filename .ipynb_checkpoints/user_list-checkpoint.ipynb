# %%
# %matplotlib inline
import pandas as pd
import pickle

with open('pandas/user.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#                               description  followers_count  friends_count  \
# 0    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 1    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 2    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 3    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 4    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 5    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 6    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 7    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 8    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 9    UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 10   UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# 11   UEC16/先ロボ ロボメカ HR/ものコン 多脚球体/team RED              413            396
# ...
